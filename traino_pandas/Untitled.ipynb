# %%
import pandas as pd

# %%
magazine = pd.read_excel('RESULTADO_3T22_POR.xlsx')

# %%
display(magazine.head())
# Out:
#       R$ milhões (exceto quando indicado)      1T16      2T16      3T16  \
# 0                                     NaN       NaN       NaN       NaN
# 1  Vendas Totais (incluindo marketplace)   2702.541  2542.376  2673.645
# 2                                     NaN       NaN       NaN       NaN
# 3                     Receita Bruta Total  2723.612  2561.533  2693.808
# 4                   Receita Líquida Total  2263.474  2147.264  2258.732
#
#        4T16      1T17      2T17      3T17      4T17      1T18  ...       3T22  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN  ...        NaN
# 1  3371.651  3338.135  3223.986   3473.27  4404.889  4466.153  ...  14154.094
# 2       NaN       NaN       NaN       NaN       NaN       NaN  ...        NaN
# 3  3392.691  3350.998  3217.228  3430.313  4322.565  4366.290  ...  10729.048
# 4  2839.275  2806.925  2699.231  2856.289  3621.805  3613.263  ...   8807.019
#
# ...

# %%
display(magazine)
# Out:
#                 R$ milhões (exceto quando indicado)      1T16      2T16  \
# 0                                               NaN       NaN       NaN
# 1            Vendas Totais (incluindo marketplace)   2702.541  2542.376
# 2                                               NaN       NaN       NaN
# 3                               Receita Bruta Total  2723.612  2561.533
# 4                             Receita Líquida Total  2263.474  2147.264
# 5                                               NaN       NaN       NaN
# 6                                       Lucro Bruto   683.564   682.486
# 7                                      Margem Bruta  0.301998   0.31784
# 8                                               NaN       NaN       NaN
# 9                                            EBITDA   144.115   163.196
# 10                                    Margem EBITDA   0.06367  0.076002
# 11                                              NaN       NaN       NaN
# ...

# %%
magazine = magazine.dropna(how='all')

# %%
display(magazine)
# Out:
#                 R$ milhões (exceto quando indicado)      1T16      2T16  \
# 1            Vendas Totais (incluindo marketplace)   2702.541  2542.376
# 3                               Receita Bruta Total  2723.612  2561.533
# 4                             Receita Líquida Total  2263.474  2147.264
# 6                                       Lucro Bruto   683.564   682.486
# 7                                      Margem Bruta  0.301998   0.31784
# 9                                            EBITDA   144.115   163.196
# 10                                    Margem EBITDA   0.06367  0.076002
# 12                                  EBITDA Ajustado   163.116   168.497
# 13                           Margem EBITDA Ajustado  0.072064  0.078471
# 15                                    Lucro Líquido     5.254    10.419
# 16                                   Margem Líquida  0.002321  0.004852
# 18                           Lucro Líquido Ajustado    17.795    13.918
# ...

# %%
magazine = magazine.dropna(how='all', axis=1)
display(magazine)
# Out:
#                 R$ milhões (exceto quando indicado)      1T16      2T16  \
# 1            Vendas Totais (incluindo marketplace)   2702.541  2542.376
# 3                               Receita Bruta Total  2723.612  2561.533
# 4                             Receita Líquida Total  2263.474  2147.264
# 6                                       Lucro Bruto   683.564   682.486
# 7                                      Margem Bruta  0.301998   0.31784
# 9                                            EBITDA   144.115   163.196
# 10                                    Margem EBITDA   0.06367  0.076002
# 12                                  EBITDA Ajustado   163.116   168.497
# 13                           Margem EBITDA Ajustado  0.072064  0.078471
# 15                                    Lucro Líquido     5.254    10.419
# 16                                   Margem Líquida  0.002321  0.004852
# 18                           Lucro Líquido Ajustado    17.795    13.918
# ...

# %%
display(magazine.shape)
# Out:
# (21, 36)

# %%
display(magazine.describe())
# Out:
#                 1T18           2T18           3T18           4T18  \
# count      21.000000      21.000000      21.000000      21.000000
# mean    25775.575064   26403.005400   26999.730981   28194.243937
# std    114637.005903  117403.676896  120171.884049  124706.158055
# min         0.038885       0.038079       0.032572       0.040379
# 25%         0.213770       0.299775       0.240420       0.241680
# 50%         8.122340       4.088500       2.197250     186.170000
# 75%       857.000000     884.000000     912.000000     953.000000
# max    526052.034000  538752.804000  551432.102000  572393.992000
#
#                 1T19           2T19           3T19           4T19  \
# count      21.000000      21.000000      21.000000      21.000000
# mean    28255.682141   28757.514046   30179.238200   32178.127190
# std    125241.263096  127541.905062  133408.974172  141181.325019
# min         0.029018       0.003380       0.026171       0.026012
# ...

# %%
display(magazine['2T18'])
# Out:
# 1       4618.764000
# 3       4487.260000
# 4       3696.185000
# 6       1108.024000
# 7          0.299775
# 9        312.401000
# 10         0.084520
# 12       314.206000
# 13         0.085008
# 15       140.746000
# 16         0.038079
# 18       141.937300
# 19         0.038401
# 21         0.270820
# 22         0.341440
# 23         0.547780
# 24         4.088500
# 25         0.661300
# 26         0.330480
# 28       884.000000
# 29    538752.804000
# Name: 2T18, dtype: float64
