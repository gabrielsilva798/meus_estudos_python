# %% [markdown]
# - link do desafio
# https://www.kaggle.com/datasets/azminetoushikwasi/lionel-messi-vs-cristiano-ronaldo-club-goals?select=messi.csv
# - os 3 arquivos já estão na pasta desse arquivo.

# %%
import pandas as pd

# %%
cr7 = pd.read_csv('cr7.csv')
data = pd.read_csv('data.csv')

# %%
display(cr7.shape)
display(messi.shape)
display(data.shape)
# Out:
# (701, 13)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_64\3099372221.py in <module>
#       1 display(cr7.shape)
# ----> 2 display(messi.shape)
#       3 display(data.shape)
#
# NameError: name 'messi' is not defined

# %%
cr7.head(9)

# %%
cr7.tail(7)
# Out:
#     Season     Competition     Matchday      Date Venue               Club  \
# 694  21/22  Premier League           33   4/16/22     H  Manchester United
# 695  21/22  Premier League           34   4/23/22     A  Manchester United
# 696  21/22  Premier League           37   4/28/22     H  Manchester United
# 697  21/22  Premier League           35  05-02-22     H  Manchester United
# 698  22/23   Europa League  Group Stage   9/15/22     A  Manchester United
# 699  22/23  Premier League           10   10/9/22     A  Manchester United
# 700  22/23   Europa League  Group Stage  10/27/22     H  Manchester United
#
#          Opponent Result Playing_Position Minute At_score  \
# 694  Norwich City   3:02               CF     76     3:02
# 695    Arsenal FC   3:01               CF     34     2:01
# 696    Chelsea FC   1:01               CF     62     1:01
# 697  Brentford FC   3:00               CF     61     2:00
# 698    FC Sheriff   0:02               CF     39     0:02
# ...

# %%
cr7 = cr7.rename(columns={'Season': 'Temporada', 'Competition':'Competição','Matchday':'Dia_da_partida', 'Date':'Data', 'Club':'Clube','Opponent':'Oponente','Result':'Resultado', 'Playing_Position':'Posição','Minute':'Minuto','Type':'Tipo','Goal_assist':'Assistência'})
cr7.head()
# Out:
#   Temporada                Competição Dia_da_partida      Data Venue  \
# 0     02/03             Liga Portugal              6  10-07-02     H
# 1     02/03             Liga Portugal              6  10-07-02     H
# 2     02/03             Liga Portugal              8  10/26/02     A
# 3     02/03  Taca de Portugal Placard   Fourth Round  11/24/02     H
# 4     02/03  Taca de Portugal Placard    Fifth Round  12/18/02     H
#
#          Clube                 Oponente Resultado Posição Minuto At_score  \
# 0  Sporting CP            Moreirense FC      3:00      LW     34     2:00
# 1  Sporting CP            Moreirense FC      3:00      LW   90+5     3:00
# 2  Sporting CP              Boavista FC      1:02     NaN     88     1:02
# 3  Sporting CP             CD Estarreja      4:01     NaN     67     3:00
# 4  Sporting CP  FC Oliveira do Hospital      8:01     NaN     13     3:00
#
#                 Tipo     Assistência
# 0           Solo run             NaN
# ...

# %%
nulos_cr7= cr7.isnull().sum()
display(nulos_cr7)
# Out:
# Temporada           0
# Competição          0
# Dia_da_partida      0
# Data                0
# Venue               0
# Clube               0
# Oponente            0
# Resultado           0
# Posição            58
# Minuto              0
# At_score            0
# Tipo               15
# Assistência       242
# dtype: int64

# %%
cr7 = cr7.drop(columns=['At_score','Assistência'])

cr7.head(7)
# Out:
#   Temporada                Competição Dia_da_partida      Data Venue  \
# 0     02/03             Liga Portugal              6  10-07-02     H
# 1     02/03             Liga Portugal              6  10-07-02     H
# 2     02/03             Liga Portugal              8  10/26/02     A
# 3     02/03  Taca de Portugal Placard   Fourth Round  11/24/02     H
# 4     02/03  Taca de Portugal Placard    Fifth Round  12/18/02     H
# 5     03/04            Premier League             11  11-01-03     H
# 6     03/04                    FA Cup    Fifth Round   2/14/04     H
#
#                Clube                 Oponente Resultado Posição Minuto  \
# 0        Sporting CP            Moreirense FC      3:00      LW     34
# 1        Sporting CP            Moreirense FC      3:00      LW   90+5
# 2        Sporting CP              Boavista FC      1:02     NaN     88
# 3        Sporting CP             CD Estarreja      4:01     NaN     67
# ...

# %%
cr7.isnull().sum()
# Out:
# Temporada          0
# Competição         0
# Dia_da_partida     0
# Data               0
# Venue              0
# Clube              0
# Oponente           0
# Resultado          0
# Posição           58
# Minuto             0
# Tipo              15
# dtype: int64

# %%
# consegui os clubes que ele joga
cr7.groupby('Clube').sum()
# Out:
#                                                            Temporada  \
# Clube
# Juventus FC        18/1918/1918/1918/1918/1918/1918/1918/1918/191...
# Manchester United  03/0403/0403/0403/0403/0403/0404/0504/0504/050...
# Real Madrid        09/1009/1009/1009/1009/1009/1009/1009/1009/100...
# Sporting CP                                02/0302/0302/0302/0302/03
#
#                                                           Competição  \
# Clube
# Juventus FC        Serie ASerie ASerie ASerie ASerie ASerie ASeri...
# Manchester United  Premier LeagueFA CupPremier LeaguePremier Leag...
# Real Madrid        LaLigaLaLigaUEFA Champions LeagueUEFA Champion...
# Sporting CP        Liga PortugalLiga PortugalLiga PortugalTaca de...
#
#                                                       Dia_da_partida  \
# Clube
# Juventus FC        445891010Group Stage12131416181919Final2122222...
# Manchester United  11Fifth Round293238Final16Third Round242525Fif...
# ...

# %%
juventus_posição = cr7.loc[cr7['Clube']== 'Juventus FC']
juventus_posição.head(13)
# Out:
#     Temporada             Competição Dia_da_partida      Data Venue  \
# 573     18/19                Serie A              4   9/16/18     H
# 574     18/19                Serie A              4   9/16/18     H
# 575     18/19                Serie A              5   9/23/18     A
# 576     18/19                Serie A              8  10-06-18     A
# 577     18/19                Serie A              9  10/20/18     H
# 578     18/19                Serie A             10  10/27/18     A
# 579     18/19                Serie A             10  10/27/18     A
# 580     18/19  UEFA Champions League    Group Stage  11-07-18     H
# 581     18/19                Serie A             12  11-11-18     A
# 582     18/19                Serie A             13  11/24/18     H
# 583     18/19                Serie A             14  12-01-18     A
# 584     18/19                Serie A             16  12/15/18     A
# 585     18/19                Serie A             18  12/26/18     A
#
# ...

# %%
# a porcentagem de posição CF é maior na juventus que a de LW.
juventus_posição.loc[juventus_posição['Posição'] =='CF'].count()/ len(juventus_posição) * 100
# Out:
# Temporada         61.386139
# Competição        61.386139
# Dia_da_partida    61.386139
# Data              61.386139
# Venue             61.386139
# Clube             61.386139
# Oponente          61.386139
# Resultado         61.386139
# Posição           61.386139
# Minuto            61.386139
# Tipo              61.386139
# dtype: float64

# %%
real_posição = cr7.loc[cr7['Clube']== 'Real Madrid']
real_posição.head(13)
# Out:
#     Temporada             Competição Dia_da_partida      Data Venue  \
# 123     09/10                 LaLiga              1   8/29/09     H
# 124     09/10                 LaLiga              2  09-12-09     A
# 125     09/10  UEFA Champions League    Group Stage   9/15/09     A
# 126     09/10  UEFA Champions League    Group Stage   9/15/09     A
# 127     09/10                 LaLiga              3   9/20/09     H
# 128     09/10                 LaLiga              3   9/20/09     H
# 129     09/10                 LaLiga              4   9/23/09     A
# 130     09/10  UEFA Champions League    Group Stage   9/30/09     H
# 131     09/10  UEFA Champions League    Group Stage   9/30/09     H
# 132     09/10                 LaLiga             13  12-05-09     H
# 133     09/10  UEFA Champions League    Group Stage  12-08-09     A
# 134     09/10  UEFA Champions League    Group Stage  12-08-09     A
# 135     09/10                 LaLiga             15  12/19/09     H
#
# ...

# %%
real_posição.isnull().sum()/len(real_posição) * 100
# Out:
# Temporada         0.000000
# Competição        0.000000
# Dia_da_partida    0.000000
# Data              0.000000
# Venue             0.000000
# Clube             0.000000
# Oponente          0.000000
# Resultado         0.000000
# Posição           3.333333
# Minuto            0.000000
# Tipo              0.000000
# dtype: float64

# %%
#parece que CF foi a posição mais jogada pelo cr7 no Real Madrid.
real_posição.loc[real_posição['Posição'] =='CF'].count()/ len(real_posição) * 100
# Out:
# Temporada         24.0
# Competição        24.0
# Dia_da_partida    24.0
# Data              24.0
# Venue             24.0
# Clube             24.0
# Oponente          24.0
# Resultado         24.0
# Posição           24.0
# Minuto            24.0
# Tipo              24.0
# dtype: float64

# %%
# usei o .fillna() para substituir os valores vazios pelas posiçaõ mais jogadas nos clubes que ele passou.
cr7.loc[cr7['Clube'] == 'Sporting CP',['Posição']].fillna('LW',)
cr7.loc[cr7['Clube'] == 'Manchester United',['Posição']].fillna('RW',)
cr7.loc[cr7['Clube'] == 'juventus',['Posição']].fillna('CF',)
cr7.loc[cr7['Clube'] == 'Real Madrid',['Posição']].fillna('CF',)
# não conseguir alterar isso na tabel final
# Out:
#     Posição
# 123      RW
# 124      CF
# 125      CF
# 126      CF
# 127      RW
# ..      ...
# 568      CF
# 569      CF
# 570      CF
# 571      LW
# 572      CF
#
# [450 rows x 1 columns]

# %%
#acbei substituíndo assim no final
cr7.loc[cr7['Clube'] == 'Sporting CP',['Posição']]='LW'
cr7.loc[cr7['Clube'] == 'Manchester United',['Posição']]='RW',
cr7.loc[cr7['Clube'] == 'juventus',['Posição']]='CF'
cr7.loc[cr7['Clube'] == 'Real Madrid',['Posição']]='CF'

# %%
cr7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temporada       701 non-null    object
#  1   Competição      701 non-null    object
#  2   Dia_da_partida  701 non-null    object
#  3   Data            701 non-null    object
#  4   Venue           701 non-null    object
#  5   Clube           701 non-null    object
#  6   Oponente        701 non-null    object
#  7   Resultado       701 non-null    object
#  8   Posição         701 non-null    object
#  9   Minuto          701 non-null    object
#  10  Tipo            686 non-null    object
# dtypes: object(11)
# memory usage: 60.4+ KB

# %% [markdown]
# ### no final da contas eu vou excluir essa coluna kkk só serviu de aprendizado.

# %%
cr7.head()
# Out:
#   Temporada                Competição Dia_da_partida      Data Venue  \
# 0     02/03             Liga Portugal              6  10-07-02     H
# 1     02/03             Liga Portugal              6  10-07-02     H
# 2     02/03             Liga Portugal              8  10/26/02     A
# 3     02/03  Taca de Portugal Placard   Fourth Round  11/24/02     H
# 4     02/03  Taca de Portugal Placard    Fifth Round  12/18/02     H
#
#          Clube                 Oponente Resultado Posição Minuto  \
# 0  Sporting CP            Moreirense FC      3:00      LW     34
# 1  Sporting CP            Moreirense FC      3:00      LW   90+5
# 2  Sporting CP              Boavista FC      1:02      LW     88
# 3  Sporting CP             CD Estarreja      4:01      LW     67
# 4  Sporting CP  FC Oliveira do Hospital      8:01      LW     13
#
#                 Tipo
# 0           Solo run
# 1             Header
# 2  Right-footed shot
# 3   Left-footed shot
# 4                NaN

# %%
cr7 = cr7.drop('Posição', axis=1)
cr7.head()
# Out:
#   Temporada                Competição Dia_da_partida      Data Venue  \
# 0     02/03             Liga Portugal              6  10-07-02     H
# 1     02/03             Liga Portugal              6  10-07-02     H
# 2     02/03             Liga Portugal              8  10/26/02     A
# 3     02/03  Taca de Portugal Placard   Fourth Round  11/24/02     H
# 4     02/03  Taca de Portugal Placard    Fifth Round  12/18/02     H
#
#          Clube                 Oponente Resultado Minuto               Tipo
# 0  Sporting CP            Moreirense FC      3:00     34           Solo run
# 1  Sporting CP            Moreirense FC      3:00   90+5             Header
# 2  Sporting CP              Boavista FC      1:02     88  Right-footed shot
# 3  Sporting CP             CD Estarreja      4:01     67   Left-footed shot
# 4  Sporting CP  FC Oliveira do Hospital      8:01     13                NaN

# %% [markdown]
# #### temos 15 tipo de gols que são nulos
# - proxima etapa a tratar

# %%
cr7.isnull().sum()
# Out:
# Temporada          0
# Competição         0
# Dia_da_partida     0
# Data               0
# Venue              0
# Clube              0
# Oponente           0
# Resultado          0
# Minuto             0
# Tipo              15
# dtype: int64

# %%
# peguei somente onde tinha nulo na coluna TIPO
cr7[cr7['Tipo'].isna()]
# Out:
#    Temporada                Competição Dia_da_partida      Data Venue  \
# 4      02/03  Taca de Portugal Placard    Fifth Round  12/18/02     H
# 12     04/05                    FA Cup    Third Round   1/19/05     A
# 29     05/06                   EFL Cup          Final   2/26/06     H
# 32     06/07            Premier League              1   8/20/06     H
# 33     06/07            Premier League              6   9/23/06     A
# 34     06/07            Premier League             10  10/28/06     A
# 36     06/07            Premier League             15  11/29/06     H
# 37     06/07            Premier League             17  12-09-06     H
# 38     06/07            Premier League             19  12/23/06     A
# 39     06/07            Premier League             19  12/23/06     A
# 40     06/07            Premier League             20  12/26/06     H
# 42     06/07            Premier League             21  12/30/06     H
# ...

# %%
# porcentagem de valores nulo em relação ao todo.
15/len(cr7['Tipo'])*100
# Out:
# 2.1398002853067046

# %%
# vou excluir a coluna tipo mesmo
cr7 = cr7.drop('Tipo',axis=1)
display(cr7)
# Out:
#     Temporada                Competição Dia_da_partida      Data Venue  \
# 0       02/03             Liga Portugal              6  10-07-02     H
# 1       02/03             Liga Portugal              6  10-07-02     H
# 2       02/03             Liga Portugal              8  10/26/02     A
# 3       02/03  Taca de Portugal Placard   Fourth Round  11/24/02     H
# 4       02/03  Taca de Portugal Placard    Fifth Round  12/18/02     H
# ..        ...                       ...            ...       ...   ...
# 696     21/22            Premier League             37   4/28/22     H
# 697     21/22            Premier League             35  05-02-22     H
# 698     22/23             Europa League    Group Stage   9/15/22     A
# 699     22/23            Premier League             10   10/9/22     A
# 700     22/23             Europa League    Group Stage  10/27/22     H
#
#                  Clube                 Oponente Resultado Minuto
# ...

# %%
cr7.info()
'\n' #quebra de página
cr7.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temporada       701 non-null    object
#  1   Competição      701 non-null    object
#  2   Dia_da_partida  701 non-null    object
#  3   Data            701 non-null    object
#  4   Venue           701 non-null    object
#  5   Clube           701 non-null    object
#  6   Oponente        701 non-null    object
#  7   Resultado       701 non-null    object
#  8   Minuto          701 non-null    object
# dtypes: object(9)
# memory usage: 49.4+ KB
# Temporada         0
# Competição        0
# Dia_da_partida    0
# Data              0
# Venue             0
# Clube             0
# Oponente          0
# Resultado         0
# Minuto            0
# dtype: int64

# %% [markdown]
# # cr7 tratado, recomendo salvar o arquivo e criar um novo arquivo para trata a tabela MESSI
# -***DEPOIS VER SE A TABELA DATA TERÁ ALGUMA FUNÇÃO***

# %%
# salvar arquivo
cr7.to_csv('cr7_pronto.csv')
